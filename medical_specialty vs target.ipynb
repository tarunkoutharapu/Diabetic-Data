# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/hrishikesh/Desktop/New_Capstones/Group 5_Diabetes/dataset_diabetes/dataset_diabetes/diabetic_data.csv')

# %%
df=df.replace('?',np.NaN)

# %%
df.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
df['medical_specialty'].dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        99493 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      3197 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  61510 non-null object
# medical_specialty           51817 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# number_emergency            101766 non-null int64
# number_inpatient            101766 non-null int64
# diag_1                      101745 non-null object
# diag_2                      101408 non-null object
# diag_3                      100343 non-null object
# number_diagnoses            101766 non-null int64
# max_glu_serum               101766 non-null object
# A1Cresult                   101766 non-null object
# metformin                   101766 non-null object
# repaglinide                 101766 non-null object
# nateglinide                 101766 non-null object
# chlorpropamide              101766 non-null object
# glimepiride                 101766 non-null object
# acetohexamide               101766 non-null object
# glipizide                   101766 non-null object
# glyburide                   101766 non-null object
# tolbutamide                 101766 non-null object
# pioglitazone                101766 non-null object
# rosiglitazone               101766 non-null object
# acarbose                    101766 non-null object
# miglitol                    101766 non-null object
# troglitazone                101766 non-null object
# tolazamide                  101766 non-null object
# examide                     101766 non-null object
# citoglipton                 101766 non-null object
# insulin                     101766 non-null object
# glyburide-metformin         101766 non-null object
# glipizide-metformin         101766 non-null object
# glimepiride-pioglitazone    101766 non-null object
# metformin-rosiglitazone     101766 non-null object
# metformin-pioglitazone      101766 non-null object
# change                      101766 non-null object
# diabetesMed                 101766 non-null object
# readmitted                  101766 non-null object
# dtypes: int64(13), object(37)
# memory usage: 38.4+ MB

# %%
df['medical_specialty']
# Out:
# 0                Pediatrics-Endocrinology
# 9                        InternalMedicine
# 12                 Family/GeneralPractice
# 13                 Family/GeneralPractice
# 17                             Cardiology
# 26                             Cardiology
# 27                        Surgery-General
# 29                             Cardiology
# 32                 Family/GeneralPractice
# 35                             Cardiology
# 40                             Cardiology
# 43                 Family/GeneralPractice
# 46                       InternalMedicine
# 61                             Cardiology
# 73                        Surgery-General
# 74                             Cardiology
# 75                             Cardiology
# 77                            Orthopedics
# 85                             Cardiology
# 90                             Cardiology
# 96                 Family/GeneralPractice
# 98                        Surgery-General
# 105                            Cardiology
# 107                Family/GeneralPractice
# 114                            Cardiology
# 115                      Gastroenterology
# 117       Surgery-Cardiovascular/Thoracic
# 118                Family/GeneralPractice
# 121                Family/GeneralPractice
# 122                      InternalMedicine
#                        ...
# 101661                   Emergency/Trauma
# 101662                   Emergency/Trauma
# 101666                            Surgeon
# 101670                   Emergency/Trauma
# 101674                   Emergency/Trauma
# 101675                        Orthopedics
# 101676                        Radiologist
# 101678                   InternalMedicine
# 101680                   Emergency/Trauma
# 101681                   Emergency/Trauma
# 101683                        Radiologist
# 101684             Family/GeneralPractice
# 101685                   Emergency/Trauma
# 101688                   Emergency/Trauma
# 101690                   InternalMedicine
# 101692                         Cardiology
# 101695                   Emergency/Trauma
# 101700                   Emergency/Trauma
# 101706                   InternalMedicine
# 101710                   Emergency/Trauma
# 101716                   Emergency/Trauma
# 101719                   InternalMedicine
# 101720             Family/GeneralPractice
# 101724             Family/GeneralPractice
# 101725                   Surgery-Thoracic
# 101735                   Emergency/Trauma
# 101743                   Emergency/Trauma
# 101747                   InternalMedicine
# 101749                        Orthopedics
# 101764                    Surgery-General
# Name: medical_specialty, Length: 51817, dtype: object

# %%
df.groupby(['medical_specialty','readmitted'])['readmitted'].agg(['count'])
# Out:
#                                              count
# medical_specialty                readmitted
# AllergyandImmunology             <30             3
#                                  >30             3
#                                  NO              1
# Anesthesiology                   <30             1
#                                  >30             3
#                                  NO              8
# Anesthesiology-Pediatric         <30             1
#                                  >30             5
#                                  NO             13
# Cardiology                       <30           425
#                                  >30          1853
#                                  NO           3074
# Cardiology-Pediatric             <30             1
#                                  >30             4
#                                  NO              2
# DCPTEAM                          >30             1
#                                  NO              5
# Dentistry                        >30             3
#                                  NO              1
# Dermatology                      >30             1
# Emergency/Trauma                 <30           846
#                                  >30          3006
#                                  NO           3713
# Endocrinology                    <30             6
#                                  >30            39
#                                  NO             75
# Endocrinology-Metabolism         <30             1
#                                  >30             1
#                                  NO              6
# Family/GeneralPractice           <30           883
# ...                                            ...
# Surgery-Colon&Rectal             <30             1
#                                  >30             3
#                                  NO              7
# Surgery-General                  <30           342
#                                  >30          1046
#                                  NO           1711
# Surgery-Maxillofacial            <30             1
#                                  >30             2
#                                  NO              8
# Surgery-Neuro                    <30            32
#                                  >30            76
#                                  NO            360
# Surgery-Pediatric                >30             2
#                                  NO              6
# Surgery-Plastic                  <30             7
#                                  >30            10
#                                  NO             24
# Surgery-PlasticwithinHeadandNeck >30             1
# Surgery-Thoracic                 <30            11
#                                  >30            30
#                                  NO             68
# Surgery-Vascular                 <30            74
#                                  >30           200
#                                  NO            259
# SurgicalSpecialty                <30             2
#                                  >30             9
#                                  NO             22
# Urology                          <30            68
#                                  >30           185
#                                  NO            432
#
# [188 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
